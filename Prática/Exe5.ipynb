# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoV1e1r4/Atividades-de-Processamento-de-Sinais-I/blob/main/Pr%C3%A1tica/Exe5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from IPython.display import Audio

# %%
fs_h, h = wavfile.read('h_banheiro.wav')
fs_t, taca = wavfile.read('sinal_taca.wav')

# %%
plt.figure(figsize=(12,4))
plt.plot(h)
plt.xlabel("Tempo")
plt.ylabel("Amplitude")
plt.title('Resposta ao impulso — banheiro')
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(taca)
plt.xlabel("Tempo")
plt.ylabel("Amplitude")
plt.title('Sinal da taça')
plt.show()
