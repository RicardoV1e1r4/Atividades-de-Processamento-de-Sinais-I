# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoV1e1r4/Atividades-de-Processamento-de-Sinais-I/blob/main/Pr%C3%A1tica1/Exe3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.Leia o arquivo *handel.wav* e faça o que se pede nos itens abaixo:
#
# (a) Gere um gráfico do sinal de áudio no domínio do tempo.
#
# (b) Escreva um código para tocar os sinais gerados. Ouça o sinal de áudio com a frequência de amostragem original do sinal original, com o dobro da frequência original e o quádruplo da frequência original.
#
# (c) Comente os resultados obtidos e compare o espectro do sinal de áudio com o espectro dos sinais das questões
# anteriores.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from IPython.display import Audio

# %%
samplerate, data = wavfile.read("handel.wav")

# Número de amostras N
N = data.shape[0]

# Vetor de tempo
time = np.arange(N) / samplerate
# print(time)
# print(N)
# print(samplerate)
# print(data.shape)
# Out:
# [0.00000000e+00 1.22070312e-04 2.44140625e-04 ... 8.92456055e+00
#  8.92468262e+00 8.92480469e+00]
# 73113
# 8192
# (73113,)

# %% [markdown]
# ## Letra a)

# %%
plt.figure(figsize=(12,6))
plt.plot(time, data)
plt.ylabel("Amplitude")
plt.xlabel("Time (s)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Letra b)

# %%
# Áudio com a frequência original
Audio(data=data, rate=samplerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Áudio com o dobro da frequência original
Audio(data=data, rate=samplerate*2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Áudio com quatro vezes frequência original
Audio(data=data, rate=samplerate*4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
